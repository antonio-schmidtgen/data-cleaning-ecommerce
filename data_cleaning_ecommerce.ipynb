# %% [markdown]
# # Data Cleaning — E-commerce Transactions

# %% [markdown]
# 🔹Imports

# %%
import pandas as pd

# %% [markdown]
# 🔹 Load data

# %%
df = pd.read_csv("data_raw/online_retail_.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("data_raw/online_retail_.csv")
#       2 df.head()
#
# File ~/Documents/data-analytics/spiced-academy/venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
# ...

# %% [markdown]
# 🔹 Inspect

# %%
df.info()
df.isnull().sum()
df.duplicated().sum()

# %% [markdown]
# 🔹 Clean missing values

# %%
# Remove rows without customer ID
df = df.dropna(subset=['Customer ID'])

# Fill missing descriptions
df['Description'] = df['Description'].fillna('Unknown')

# %% [markdown]
# 🔹 Remove duplicates

# %%
df = df.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = df.drop_duplicates()
#
# NameError: name 'df' is not defined

# %% [markdown]
# 🔹 Fix data types

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
df['Customer ID'] = df['Customer ID'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
#       2 df['Customer ID'] = df['Customer ID'].astype(int)
#
# NameError: name 'df' is not defined

# %% [markdown]
# 🔹 Remove invalid data

# %%
# Remove returned orders
df = df[df['Quantity'] > 0]

# Remove invalid prices
df = df[df['Price'] > 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Remove returned orders
# ----> 2 df = df[df['Quantity'] > 0]
#       4 # Remove invalid prices
#       5 df = df[df['Price'] > 0]
#
# NameError: name 'df' is not defined

# %% [markdown]
# 🔹 Feature engineering

# %%
df['TotalPrice'] = df['Quantity'] * df['Price']

df['Year'] = df['InvoiceDate'].dt.year
df['Month'] = df['InvoiceDate'].dt.month
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df['TotalPrice'] = df['Quantity'] * df['Price']
#       3 df['Year'] = df['InvoiceDate'].dt.year
#       4 df['Month'] = df['InvoiceDate'].dt.month
#
# NameError: name 'df' is not defined

# %% [markdown]
# 🔹 Save clean data

# %%
df.to_csv("data_clean/clean_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.to_csv("data_clean/clean_data.csv", index=False)
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Negative quantities represent product returns → remove for revenue analysis
